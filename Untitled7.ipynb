# %%
#Data Analysis of ABC Company

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv("Analysis.csv")
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# Display the first few rows of the dataset to understand its structure
data.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
import numpy as np

# Replace the "Height" column with random numbers between 150 and 180
data['Height'] = np.random.randint(150, 181, size=data.shape[0])

# Display the first few rows to confirm the changes
data.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     169     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     166     235
# 2   John Holland  Boston Celtics      30       SG   27     156     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     169     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     168     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
# Calculate the distribution of employees across each team
team_distribution = data['Team'].value_counts()

# Calculate the percentage split
team_percentage = team_distribution / team_distribution.sum() * 100

# Combine into a single DataFrame for better visualization
team_distribution_df = pd.DataFrame({
    'Team': team_distribution.index,
    'Number of Employees': team_distribution.values,
    'Percentage': team_percentage.values
})

# Display the team distribution DataFrame
team_distribution_df.reset_index(drop=True, inplace=True)
team_distribution_df
# Out:
#                       Team  Number of Employees  Percentage
# 0     New Orleans Pelicans                   19    4.148472
# 1        Memphis Grizzlies                   18    3.930131
# 2                Utah Jazz                   16    3.493450
# 3          New York Knicks                   16    3.493450
# 4          Milwaukee Bucks                   16    3.493450
# 5            Brooklyn Nets                   15    3.275109
# 6   Portland Trail Blazers                   15    3.275109
# 7    Oklahoma City Thunder                   15    3.275109
# 8           Denver Nuggets                   15    3.275109
# 9       Washington Wizards                   15    3.275109
# 10              Miami Heat                   15    3.275109
# 11       Charlotte Hornets                   15    3.275109
# 12           Atlanta Hawks                   15    3.275109
# 13       San Antonio Spurs                   15    3.275109
# 14         Houston Rockets                   15    3.275109
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the size of the plot
plt.figure(figsize=(10,6))

# Create a bar plot for the number of employees per team
sns.barplot(x='Number of Employees', y='Team', data=team_distribution_df, palette='magma')

# Add title and labels
plt.title('Distribution of Employees Across Each Team')
plt.xlabel('Number of Employees')
plt.ylabel('Team')

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\gauth\AppData\Local\Temp\ipykernel_16796\2666844834.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Number of Employees', y='Team', data=team_distribution_df, palette='magma')

# %%
#Teams like the New Orleans Pelicans, Memphis Grizzlies, Utah Jazz, New York Knicks, and Milwaukee Bucks have the highest number of employees, each having around 15-19 employees.
#The percentage of employees across these teams ranges from about 3% to 4%

# %%
# Calculate the distribution of employees based on their positions
position_distribution = data['Position'].value_counts()

# Calculate the percentage split
position_percentage = position_distribution / position_distribution.sum() * 100

# Combine into a single DataFrame for better visualization
position_distribution_df = pd.DataFrame({
    'Position': position_distribution.index,
    'Number of Employees': position_distribution.values,
    'Percentage': position_percentage.values
})

# Display the position distribution DataFrame
position_distribution_df.reset_index(drop=True, inplace=True)
position_distribution_df
# Out:
#   Position  Number of Employees  Percentage
# 0       SG                  102   22.270742
# 1       PF                  100   21.834061
# 2       PG                   92   20.087336
# 3       SF                   85   18.558952
# 4        C                   79   17.248908

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.barplot(x='Number of Employees', y='Position', data=position_distribution_df, palette='icefire')
plt.title('Segregation of Employees Based on Positions')
plt.xlabel('Number of Employees')
plt.ylabel('Position')
plt.tight_layout()
# Out:
# C:\Users\gauth\AppData\Local\Temp\ipykernel_16796\286313777.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Number of Employees', y='Position', data=position_distribution_df, palette='icefire')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.barplot(x=age_group_distribution.index, y=age_group_distribution.values, palette='viridis')
plt.title('Distribution of Employees Across Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Number of Employees')
plt.show()
# Out:
# C:\Users\gauth\AppData\Local\Temp\ipykernel_16796\941573325.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=age_group_distribution.index, y=age_group_distribution.values, palette='viridis')

# %%
#Predominant age group is between 25-29 with more than 175 employees

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot total salary per team
plt.figure(figsize=(12, 6))
sns.barplot(x='Salary', y='Team', data=team_salary)
plt.title('Total Salary Expenditure per Team')
plt.xlabel('Total Salary')
plt.ylabel('Team')
plt.show()

# Plot total salary per position
plt.figure(figsize=(12, 6))
sns.barplot(x='Salary', y='Position', data=position_salary)
plt.title('Total Salary Expenditure per Position')
plt.xlabel('Total Salary')
plt.ylabel('Position')
plt.show()

# %%
#The team Cleveland Cavaliers have higher salary and position C gains more salary

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting the scatter plot with a regression line
plt.figure(figsize=(10, 6))
sns.regplot(x='Age', y='Salary', data=data)
plt.title('Correlation between Age and Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %%
#the scatterplot shows the corelation between age and salary which indicates salary is increasing as experience and age increses

# %%
#DATA STORY
#The Boston Celtics have the highest number of employees, indicating a larger team size compared to others.

# %%
#The majority of employees occupy the SG positions

# %%
#Predominant Age Group:
#The 20-25 age group is the most common

# %%
#Salary Expenditure:
#The Boston Celtics have the highest total salary expenditure
#The Center (C) and Forward positions (PF, SF) have higher salary expenditures

# %%
#Age and Salary Correlation:
#The weak positive correlation between age and salary suggests that while there is a tendency for older players to earn more

# %%
# Task 1: Distribution of employees across each team and percentage split
import pandas as pd
data = pd.read_csv("Analysis.csv")
data

team_distribution = data['Team'].value_counts()
team_percentage = (team_distribution / team_distribution.sum()) * 100

# Task 2: Segregate employees based on their positions
position_distribution = data['Position'].value_counts()

# Task 3: Identify the predominant age group among employees
age_groups = pd.cut(data['Age'], bins=[20, 25, 30, 35, 40, 45, 50], right=False)
age_group_distribution = age_groups.value_counts().sort_index()

# Task 4: Team and position with the highest salary expenditure
team_salary_expenditure = data.groupby('Team')['Salary'].sum()
position_salary_expenditure = data.groupby('Position')['Salary'].sum()

# Plot for Task 1: Team distribution
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12, 6))
team_distribution.plot(kind='bar', color='skyblue')
plt.title('Distribution of Employees Across Teams')
plt.xlabel('Team')
plt.ylabel('Number of Employees')
plt.grid(True)
plt.show()

# Plot for Task 1: Team percentage split
plt.figure(figsize=(12, 6))
team_percentage.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Percentage Split of Employees Across Teams')
plt.ylabel('')
plt.show()

# Plot for Task 2: Position distribution
plt.figure(figsize=(12, 6))
position_distribution.plot(kind='bar', color='lightgreen')
plt.title('Distribution of Employees Based on Positions')
plt.xlabel('Position')
plt.ylabel('Number of Employees')
plt.grid(True)
plt.show()

# Plot for Task 3: Predominant age group
plt.figure(figsize=(12, 6))
age_group_distribution.plot(kind='bar', color='salmon')
plt.title('Distribution of Employees by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Number of Employees')
plt.grid(True)
plt.show()

# Plot for Task 4: Team salary expenditure
plt.figure(figsize=(12, 6))
team_salary_expenditure.plot(kind='bar', color='orange')
plt.title('Total Salary Expenditure by Team')
plt.xlabel('Team')
plt.ylabel('Total Salary Expenditure')
plt.grid(True)
plt.show()

# Plot for Task 4: Position salary expenditure
plt.figure(figsize=(12, 6))
position_salary_expenditure.plot(kind='bar', color='purple')
plt.title('Total Salary Expenditure by Position')
plt.xlabel('Position')
plt.ylabel('Total Salary Expenditure')
plt.grid(True)
plt.show()

# Re-plot Task 5: Correlation between Age and Salary
plt.figure(figsize=(10, 6))
sns.regplot(x='Age', y='Salary', data=data_clean, scatter_kws={'s': 50}, line_kws={'color': 'red'})
plt.title(f'Correlation between Age and Salary: {correlation:.2f}')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 76
#      74 # Re-plot Task 5: Correlation between Age and Salary
#      75 plt.figure(figsize=(10, 6))
# ---> 76 sns.regplot(x='Age', y='Salary', data=data_clean, scatter_kws={'s': 50}, line_kws={'color': 'red'})
#      77 plt.title(f'Correlation between Age and Salary: {correlation:.2f}')
#      78 plt.xlabel('Age')
#
# NameError: name 'data_clean' is not defined
